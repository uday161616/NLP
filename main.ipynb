# %%
nltk.tokenize
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nltk.tokenize
#
# NameError: name 'nltk' is not defined
