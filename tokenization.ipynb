# %%
import nltk

# %%
corpus = ''' welcome to uday's world! welcome to my youtube channel.
lets learn naturallanguage processing.'''

# %%
corpus
# Out:
# " welcome to uday's world! welcome to my youtube channel.\nlets learn naturallanguage processing."

# %%
from nltk import sent_tokenize
documnets = sent_tokenize(corpus)

# %%
type(documnets)
# Out:
# list

# %%
for sent in documnets:
    print(sent)
# Out:
#  welcome to uday's world!
# welcome to my youtube channel.
# lets learn naturallanguage processing.

# %%
from nltk import word_tokenize
word_tokenize(corpus)
# Out:
# ['welcome',
#  'to',
#  'uday',
#  "'s",
#  'world',
#  '!',
#  'welcome',
#  'to',
#  'my',
#  'youtube',
#  'channel',
#  '.',
#  'lets',
#  'learn',
#  'naturallanguage',
#  'processing',
#  '.']

# %%
for sentences in documnets:
    print(word_tokenize(sentences))
# Out:
# ['welcome', 'to', 'uday', "'s", 'world', '!']
# ['welcome', 'to', 'my', 'youtube', 'channel', '.']
# ['lets', 'learn', 'naturallanguage', 'processing', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['welcome',
#  'to',
#  'uday',
#  "'s",
#  'world',
#  '!',
#  'welcome',
#  'to',
#  'my',
#  'youtube',
#  'channel.',
#  'lets',
#  'learn',
#  'naturallanguage',
#  'processing',
#  '.']
